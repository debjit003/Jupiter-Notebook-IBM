# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Debjit Roy

# %% [markdown]
# #### Data Scientist

# %% [markdown]
# *I am interested in Data Science because I used to know some interesting things like analysis, python and liberies, some amazing tools and AI/ML models which are really great to work with.
# I really want to work as a Data Scientist to solve real-world problems using data.*

# %% [markdown]
# The following python code is for printing a addition of two integer variable.

# %%
x=12
y=45
print(x+y)
# Out:
# 57

# %% [markdown]
# 1. Bike
# 2. Car
# 3. Van
# 4. Jeep
# ![roadview.jpg](attachment:roadview.jpg)
# https://www.google.com/
